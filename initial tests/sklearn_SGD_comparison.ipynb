# %%
from sklearn.linear_model import SGDClassifier
from utilities import *

# %%
X_train, X_test, y_train, y_test = prepare_data(get_pT=False)
# Out:
# found preprepared data in ..\data\ZMUMU_EGZ_extended_np_pd

# %%
hinge_sgd_clf = SGDClassifier(loss="hinge", max_iter=10000, tol=1e-3, random_state=42, learning_rate="adaptive",eta0=0.1)
hinge_sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(eta0=0.1, learning_rate='adaptive', max_iter=10000,
#               random_state=42)

# %%
y_pred_hinge = hinge_sgd_clf.predict(X_test)
evaluate_sklearn_model(y_test, y_pred_hinge)
# Out:
# Accuracy: 0.9425
# Recall: 0.9537
# Precision: 0.9011
# F1 Score: 0.9266
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.94      0.95     28610
#          1.0       0.90      0.95      0.93     17572
#
#     accuracy                           0.94     46182
#    macro avg       0.94      0.94      0.94     46182
# weighted avg       0.94      0.94      0.94     46182
#
# Confusion Matrix:
#  [[26770  1840]
#  [  814 16758]]
# Mean Squared Error: 0.0575

# %%
precision_recall(hinge_sgd_clf, X_test, y_test)

# %%
compute_roc(hinge_sgd_clf, X_test, y_test)
plot_roc(fpr, tpr, roc_auc)

# %%
log_sgd_clf = SGDClassifier(loss="log_loss", max_iter=10000, tol=1e-3, random_state=42, learning_rate="adaptive",eta0=0.1)
log_sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(eta0=0.1, learning_rate='adaptive', loss='log_loss',
#               max_iter=10000, random_state=42)

# %%
y_pred_log = log_sgd_clf.predict(X_test)
evaluate_sklearn_model(y_test, y_pred_log)
# Out:
# Accuracy: 0.9427
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     28279
#          1.0       0.92      0.94      0.93     17903
#
#     accuracy                           0.94     46182
#    macro avg       0.94      0.94      0.94     46182
# weighted avg       0.94      0.94      0.94     46182
#
# Confusion Matrix:
#  [[26728  1551]
#  [ 1096 16807]]
# Mean Squared Error:
#  0.05731670347754536

# %%
huber_sgd_clf = SGDClassifier(loss="modified_huber", max_iter=10000, tol=1e-3, random_state=42, learning_rate="adaptive", eta0=0.1)
huber_sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(eta0=0.1, learning_rate='adaptive', loss='modified_huber',
#               max_iter=10000, random_state=42)

# %%
y_pred_huber = huber_sgd_clf.predict(X_test)
evaluate_sklearn_model(y_test, y_pred_huber)
# Out:
# Accuracy: 0.9426
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     28279
#          1.0       0.92      0.94      0.93     17903
#
#     accuracy                           0.94     46182
#    macro avg       0.94      0.94      0.94     46182
# weighted avg       0.94      0.94      0.94     46182
#
# Confusion Matrix:
#  [[26726  1553]
#  [ 1096 16807]]
# Mean Squared Error:
#  0.057360010393659865

# %%
squared_sgd_clf = SGDClassifier(loss="squared_hinge", max_iter=10000, tol=1e-3, random_state=42, learning_rate="adaptive", eta0=0.1)
squared_sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(eta0=0.1, learning_rate='adaptive', loss='squared_hinge',
#               max_iter=10000, random_state=42)

# %%
y_pred_squared = squared_sgd_clf.predict(X_test)
evaluate_sklearn_model(y_test, y_pred_squared)
# Out:
# Accuracy: 0.9413
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.95      0.95     28279
#          1.0       0.92      0.93      0.92     17903
#
#     accuracy                           0.94     46182
#    macro avg       0.94      0.94      0.94     46182
# weighted avg       0.94      0.94      0.94     46182
#
# Confusion Matrix:
#  [[26768  1511]
#  [ 1198 16705]]
# Mean Squared Error:
#  0.05865921787709497

# %%
perceptron_sgd_clf = SGDClassifier(loss="perceptron", max_iter=10000, tol=1e-3, random_state=42)
perceptron_sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(loss='perceptron', max_iter=10000, random_state=42)

# %%
y_pred_perceptron = perceptron_sgd_clf.predict(X_test)
evaluate_sklearn_model(y_test, y_pred_perceptron)
# Out:
# Accuracy: 0.9258
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.89      0.94     28279
#          1.0       0.85      0.99      0.91     17903
#
#     accuracy                           0.93     46182
#    macro avg       0.92      0.94      0.92     46182
# weighted avg       0.93      0.93      0.93     46182
#
# Confusion Matrix:
#  [[25103  3176]
#  [  251 17652]]
# Mean Squared Error:
#  0.07420640076220172
